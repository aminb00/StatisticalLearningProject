# %% [markdown]
# # Linear Models

# %%
# Librerie base
import numpy as np
import pandas as pd

# Visualizzazione
import matplotlib.pyplot as plt  
import seaborn as sns

# Modelli statistici
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor as VIF
from statsmodels.stats.anova import anova_lm

# Libreria ISLP (Statistical Learning)
from ISLP import load_data
from ISLP.models import (ModelSpec as MS ,summarize, poly)

# %% [markdown]
# ### usiamo i dati engineered con log-price

# %%
data=pd.read_csv("Data/aircraft_price_cleaned_log.csv")
data.columns
target = "price"

# %%
numeric_data=data.select_dtypes(include=[np.number])
numeric_data
# Out:
#      engine_power  max_speed  cruise_speed  stall_speed  fuel_tank  \
# 0        4.976734   4.644391      4.510860         46.0   3.583519
# 1        4.442651   4.488636      4.418841         44.0   2.708050
# 2        4.499810   4.499810      4.356709         37.0   2.944439
# 3        4.442651   4.477337      4.356709         37.0   2.944439
# 4        4.174387   4.418841      4.304065         33.0   2.639057
# ..            ...        ...           ...          ...        ...
# 502      6.907755   5.860786      5.811141         56.0   8.247744
# 503      6.579251   5.743003      5.662960         89.0   6.359574
# 504      6.579251   5.669881      5.616771         87.0   5.966147
# 505      6.429719   5.616771      5.598422         77.0   5.945421
# 506      6.429719   5.645447      5.594711         75.0   5.945421
#
#      all_eng_roc  out_eng_roc  takeoff_distance  landing_distance  \
# 0       6.109248     6.802395          7.170120          7.625595
# ...

# %% [markdown]
# ## Multiple Linear Regression

# %%
# y = b*X + e (perform a regression using all of the predictors)

numeric_data = data.select_dtypes(include=[np.number])
terms = numeric_data.drop(columns=[target])
y= data[target]
X= MS(terms).fit_transform(data) 
print(X.columns)
print(y.head)
# Out:
# Index(['intercept', 'engine_power', 'max_speed', 'cruise_speed', 'stall_speed',
#        'fuel_tank', 'all_eng_roc', 'out_eng_roc', 'takeoff_distance',
#        'landing_distance', 'empty_weight', 'length', 'wing_span', 'range'],
#       dtype='object')
# <bound method NDFrame.head of 0      14.077875
# 1      14.022525
# 2      14.285514
# 3      14.077875
# 4      14.038654
#          ...
# 502    15.226498
# 503    15.091990
# 504    14.978661
# 505    14.991084
# 506    14.966083
# Name: price, Length: 507, dtype: float64>

# %%
model= sm.OLS(y,X)
results= model.fit()
print(results.summary())

#mse and rmse
mse = np.mean((y - results.predict(X)) ** 2)
rmse = np.sqrt(mse)
print("RMSE: ", rmse)

#convert y de-log  trasformando e poi calcola MSE
y_pred = results.predict(X)
y_pred = np.exp(y_pred)
y_pred[:5]
y[:5]
y_true = np.exp(y)
y[:5]
mse = np.mean((y_true - y_pred) ** 2)
#RMSE
rmse = np.sqrt(mse)
print("RMSE: ", rmse)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.865
# Model:                            OLS   Adj. R-squared:                  0.861
# Method:                 Least Squares   F-statistic:                     243.1
# Date:                Wed, 18 Jun 2025   Prob (F-statistic):          9.49e-205
# Time:                        21:24:56   Log-Likelihood:                 237.48
# No. Observations:                 507   AIC:                            -447.0
# Df Residuals:                     493   BIC:                            -387.8
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# intercept            8.3258      0.560     14.862      0.000       7.225       9.426
# ...

# %%
significant_vars = results.pvalues[results.pvalues < 0.05]
print("\nVariabili significative (p-value < 0.05):")
print(significant_vars)

insignificant_vars = results.pvalues[results.pvalues >= 0.05]
print("\nVariabili insignificanti (p-value >= 0.05):")
print(insignificant_vars)
# Out:
# Variabili significative (p-value < 0.05):
# intercept           1.497781e-41
# max_speed           1.528253e-06
# cruise_speed        1.747522e-22
# fuel_tank           2.003427e-02
# all_eng_roc         1.156960e-05
# out_eng_roc         2.046785e-03
# takeoff_distance    2.035095e-03
# landing_distance    1.387614e-07
# empty_weight        5.991965e-03
# wing_span           5.425388e-05
# dtype: float64
#
# Variabili insignificanti (p-value >= 0.05):
# engine_power    0.711508
# stall_speed     0.360340
# length          0.112868
# range           0.245947
# dtype: float64

# %% [markdown]
# #### Ottimo feature engineering e selection : non abbiamo feeatures con pvalue non significativo

# %%
# getting goodness of fit
print("R2", results.rsquared)
print("RSE", np.sqrt(results.scale))
# Out:
# R2 0.8650405376914706
# RSE 0.15361013678164634

# %%
#RSE delog-transformato
RSE_delog = np.sqrt(results.scale) * np.mean(np.exp(data[target]))
print("RSE", RSE_delog)
# Out:
# RSE 362930.54966539575

# %%
#VIF su regressione lineare multipla su X
X = sm.add_constant(X)
vif_data = pd.DataFrame()
vif_data["Regressor"] = X.columns
vif_data["VIF"] = [VIF(X.values, i) for i in range(X.shape[1])]
vif_data = vif_data.sort_values("VIF", ascending=False)
print(vif_data)
# Out:
#            Regressor          VIF
# 0          intercept  6743.021598
# 9   landing_distance    51.640063
# 1       engine_power    21.655624
# 11            length    19.161687
# 5          fuel_tank    18.816608
# 10      empty_weight    16.688598
# 3       cruise_speed    10.567482
# 12         wing_span     6.125056
# 6        all_eng_roc     5.814229
# 4        stall_speed     5.522038
# 2          max_speed     5.491074
# 8   takeoff_distance     5.256950
# 7        out_eng_roc     5.132334
# 13             range     4.142212

# %%
#Residuals analysis
residuals = results.resid
residuals[:5]
plt.figure(figsize=(10, 6))
sns.histplot(residuals, bins=30, kde=True)
plt.title('Residuals Distribution')
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.show()

# Residuals vs Fitted
plt.figure(figsize=(10, 6))
plt.scatter(results.fittedvalues, residuals, alpha=0.6)
plt.axhline(0, color='red', linestyle='--')
plt.title('Residuals vs Fitted Values')
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.show()

# Residuals vs Leverage
fig, ax = plt.subplots(figsize=(8, 8))
sm.graphics.influence_plot(results, ax=ax, criterion="cooks")
plt.title('Influence Plot')
plt.show()

# %% [markdown]
# # 80-20 Cross Validation

# %%
from functools import partial
from sklearn.model_selection import (cross_validate ,KFold ,ShuffleSplit)
from sklearn.base import clone
from ISLP.models import sklearn_sm #a wrapper that enables us to easily use the cross-validation tools of sklearn with models fit by statsmodels
from sklearn.model_selection import train_test_split

# %%
data_train, data_test = train_test_split(data, test_size=0.2, random_state=42)
data.columns
# Out:
# Index(['model_name', 'engine_type', 'engine_power', 'max_speed',
#        'cruise_speed', 'stall_speed', 'fuel_tank', 'all_eng_roc',
#        'out_eng_roc', 'takeoff_distance', 'landing_distance', 'empty_weight',
#        'length', 'wing_span', 'range', 'price'],
#       dtype='object')

# %%
# Specifica il modello con più variabili
# Puoi includere, ad esempio: horsepower, weight, displacement, acceleration, cylinders

# Prima controlliamo le colonne numeriche disponibili
numeric_cols = data.select_dtypes(include=[np.number]).columns.drop('price')
print("Colonne numeriche disponibili:")
print(numeric_cols.tolist())

# Usiamo un subset delle variabili numeriche più importanti
selected_features = ['engine_power', 'max_speed', 'cruise_speed', 'fuel_tank', 'range']

# Costruisci le matrici X e y per il training set  
hp_mm = MS(selected_features)
X_train = hp_mm.fit_transform(data_train)
y_train = data_train['price']

# Costruisci il modello
model = sm.OLS(y_train, X_train)
results = model.fit()

# Stampa i risultati
print(results.summary())
# Out:
# Colonne numeriche disponibili:
# ['engine_power', 'max_speed', 'cruise_speed', 'stall_speed', 'fuel_tank', 'all_eng_roc', 'out_eng_roc', 'takeoff_distance', 'landing_distance', 'empty_weight', 'length', 'wing_span', 'range']
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.849
# Model:                            OLS   Adj. R-squared:                  0.847
# Method:                 Least Squares   F-statistic:                     448.8
# Date:                Wed, 18 Jun 2025   Prob (F-statistic):          2.53e-161
# Time:                        21:24:58   Log-Likelihood:                 161.90
# No. Observations:                 405   AIC:                            -311.8
# Df Residuals:                     399   BIC:                            -287.8
# Df Model:                           5
# Covariance Type:            nonrobust
# ...

# %%
print("R2", results.rsquared)
# Out:
# R2 0.8490464900187695

# %%
# evaluate the model using the MSE on the validation data
X_valid = hp_mm.transform(data_test)
y_valid = data_test['price']
valid_pred = results.predict(X_valid)
mse=np.mean((y_valid - valid_pred)**2)
print("MSE", mse)
# Out:
# MSE 0.02691011702653133

# %%
# evaluate the model using the MSE on the validation data
X_valid = hp_mm.transform(data_test)
y_valid = data_test['price']
valid_pred = results.predict(X_valid)
mse=np.mean((y_valid - valid_pred)**2)
print("MSE", mse)
# Out:
# MSE 0.02691011702653133

# %%
# de log trasformami l'MSE
mse_de_log = mse * np.mean(np.exp(data['price']))
print("MSE de log", mse_de_log)
# Out:
# MSE de log 63579.811649292555

# %%
# Analisi bias-variance al variare della test size

test_sizes = np.linspace(0.1, 0.9, 9)
mse_list = []
mse_delog_list = []
r2_train_list = []
r2_test_list = []

features = selected_features
target = 'price'

for test_size in test_sizes:
    data_train, data_test = train_test_split(data, test_size=test_size, random_state=42)

    hp_mm = MS(features)
    X_train = hp_mm.fit_transform(data_train)
    y_train = data_train[target]

    model = sm.OLS(y_train, X_train)
    results = model.fit()

    # R^2 in train
    r2_train = results.rsquared
    r2_train_list.append(r2_train)

    # Validazione
    X_test = hp_mm.transform(data_test)
    y_test = data_test[target]
    y_pred = results.predict(X_test)

    mse = np.mean((y_test - y_pred) ** 2)
    mse_list.append(mse)

    # De-log: supponiamo che 'price' sia logaritmico
    mse_delog = mse * np.mean(np.exp(data[target]))
    mse_delog_list.append(mse_delog)

    # R² test manuale
    ss_tot = np.sum((y_test - np.mean(y_test)) ** 2)
    ss_res = np.sum((y_test - y_pred) ** 2)
    r2_test = 1 - ss_res / ss_tot
    r2_test_list.append(r2_test)

# --- PLOT 1: MSE vs Test Size ---
plt.figure(figsize=(10, 5))
plt.plot(test_sizes, mse_list, label="MSE (log scale)")
plt.plot(test_sizes, mse_delog_list, label="MSE (de-log scale)")
plt.xlabel("Test Size")
plt.ylabel("Mean Squared Error")
plt.title("MSE vs Test Size")
plt.legend()
plt.grid(True)
plt.show()

# --- PLOT 2: Bias-Variance Tradeoff ---
plt.figure(figsize=(10, 5))
plt.plot(test_sizes, r2_train_list, label="Train R-squared", marker='o')
plt.plot(test_sizes, r2_test_list, label="Test R-squared", marker='o')
plt.xlabel("Test Size")
plt.ylabel("R-squared")
plt.title("Bias-Variance Tradeoff")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # K=10 Fold Cross Validation

# %% [markdown]
# ## codice libro ISLP

# %%
from sklearn.linear_model import LinearRegression

# definiamo modello e dati
model = LinearRegression()
# Usa solo le colonne numeriche come feature
X = data.select_dtypes(include=[np.number]).drop(columns=['price'])
Y = numeric_data['price']

# 10‐fold CV
kf = KFold(n_splits=10, shuffle=True, random_state=1)
cv_results = cross_validate(model, X, Y, cv=kf)

# errore medio (qui R² medio)
cv_err = np.mean(cv_results['test_score'])
print(cv_err)
# Out:
# 0.8281516990961657

# %% [markdown]
# ## codice alternativo per K=10 Fold Cross Validation e mostrare i risultati

# %%
import numpy as np
import pandas as pd
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import KFold, cross_validate

# --- 1) Prepara dati e CV ---
X = data.select_dtypes(include=[np.number]).drop(columns=['price'])
Y = numeric_data['price']
kf = KFold(n_splits=10, shuffle=True, random_state=1)

# strutture per raccogliere inferenza e metriche
coef_list, se_list, t_list, p_list, ci_lo_list, ci_hi_list = [], [], [], [], [], []
r2_list, mse_list = [], []

# --- 2) Loop sui fold ---
for train_idx, test_idx in kf.split(X):
    X_tr, X_te = X.iloc[train_idx], X.iloc[test_idx]
    y_tr, y_te = y.iloc[train_idx], y.iloc[test_idx]

    # fit sul train
    model = LinearRegression().fit(X_tr, y_tr)
    y_pred_tr = model.predict(X_tr)
    y_pred_te = model.predict(X_te)

    # inferenza sul train
    n_tr, p = X_tr.shape
    resid = y_tr - y_pred_tr
    sigma2 = np.sum(resid**2) / (n_tr - p - 1)

    X_int = np.column_stack((np.ones(n_tr), X_tr.values))
    cov = sigma2 * np.linalg.inv(X_int.T @ X_int)
    se    = np.sqrt(np.diag(cov))
    coef  = np.concatenate(([model.intercept_], model.coef_))
    tstat = coef / se
    pval  = 2 * (1 - stats.t.cdf(np.abs(tstat), df=n_tr - p - 1))
    ci    = np.vstack((coef - 1.96*se, coef + 1.96*se)).T

    # raccogli inferenza
    coef_list .append(coef)
    se_list   .append(se)
    t_list    .append(tstat)
    p_list    .append(pval)
    ci_lo_list.append(ci[:,0])
    ci_hi_list.append(ci[:,1])

    # raccogli metriche sul test
    r2_list .append(r2_score(y_te, y_pred_te))
    mse_list.append(mean_squared_error(y_te, y_pred_te))

# --- 3) Aggrega risultati inferenziali ---
coef_arr  = np.vstack(coef_list)
se_arr    = np.vstack(se_list)
t_arr     = np.vstack(t_list)
p_arr     = np.vstack(p_list)
ci_lo_arr = np.vstack(ci_lo_list)
ci_hi_arr = np.vstack(ci_hi_list)

idx = ['intercept'] + list(X.columns)
infer_df = pd.DataFrame({
    'coef_mean':  coef_arr.mean(axis=0),
    'coef_std':   coef_arr.std(axis=0),
    'se_mean':    se_arr.mean(axis=0),
    't_mean':     t_arr.mean(axis=0),
    'p_mean':     p_arr.mean(axis=0),
    'CI95_lo':    ci_lo_arr.mean(axis=0),
    'CI95_hi':    ci_hi_arr.mean(axis=0),
}, index=idx)

# --- 4) Metriche CV ---
cv_metrics = {
    'R2_mean':  np.mean(r2_list),
    'R2_std':   np.std(r2_list),
    'MSE_mean': np.mean(mse_list),
    'MSE_std':  np.std(mse_list)
}

# --- 5) Stampa ---
print("=== K-Fold CV Metrics ===")
print(f"R² mean = {cv_metrics['R2_mean']:.4f} ± {cv_metrics['R2_std']:.4f}")
print(f"MSE mean = {cv_metrics['MSE_mean']:.4f} ± {cv_metrics['MSE_std']:.4f}\n")
#RMSE delog
rmse_delog = np.sqrt(cv_metrics['MSE_mean']) * np.mean(np.exp(data['price']))
print(f"RMSE delog = {rmse_delog:.4f} ± {cv_metrics['MSE_std']:.4f}\n")
print("=== Inferential Summary (aggregato sui 10 train-fold) ===")
print(infer_df)

#variables significative e non significative
significant_vars = infer_df[infer_df['p_mean'] < 0.05]
print("\nVariabili significative (p-value < 0.05):")
print(significant_vars)
insignificant_vars = infer_df[infer_df['p_mean'] >= 0.05]
print("\nVariabili insignificanti (p-value >= 0.05):")
print(insignificant_vars)
# Out:
# === K-Fold CV Metrics ===
# R² mean = 0.8282 ± 0.0585
# MSE mean = 0.0275 ± 0.0080
#
# RMSE delog = 391503.2695 ± 0.0080
#
# === Inferential Summary (aggregato sui 10 train-fold) ===
#                   coef_mean  coef_std   se_mean     t_mean    p_mean  \
# intercept          8.313682  0.302131  0.591973  14.053751  0.000000
# engine_power       0.011473  0.021459  0.031209   0.371167  0.542771
# max_speed          0.174700  0.026200  0.037475   4.639925  0.000017
# cruise_speed       0.504015  0.038734  0.051804   9.726430  0.000000
# stall_speed        0.000905  0.000523  0.001037   0.873442  0.429640
# fuel_tank          0.038711  0.006621  0.017625   2.193091  0.037529
# all_eng_roc        0.118742  0.015846  0.028362   4.178689  0.000078
# out_eng_roc       -0.098686  0.006210  0.034041  -2.900795  0.004655
# takeoff_distance   0.121017  0.009197  0.041664   2.907128  0.004843
# landing_distance  -0.324827  0.058783  0.065043  -5.047794  0.000020
# ...

# %% [markdown]
# Ovviamente con la crossvalidazione perdo un po’ di R².

# %%
mean_r2 = np.mean(r2_list)

plt.figure(figsize=(10, 5))
plt.plot(range(1, len(r2_list)+1), r2_list, marker='o', label='R² per fold')
plt.axhline(mean_r2, color='red', linestyle='--', label=f'Media R² = {mean_r2:.3f}')
plt.xlabel('Fold number')
plt.ylabel('R²')
plt.title('R² per Fold (K-Fold CV)')
plt.legend()
plt.grid(True)
plt.show()

# %%
mean_mse = np.mean(mse_list)

plt.figure(figsize=(10, 5))
plt.plot(range(1, len(mse_list)+1), mse_list, marker='o', color='red', label='MSE per fold')
plt.axhline(mean_mse, color='blue', linestyle='--', label=f'Mean MSE = {mean_mse:.4f}')
plt.xlabel('Fold number')
plt.ylabel('Mean Squared Error (MSE)')
plt.title('MSE per Fold (K-Fold CV)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.boxplot(r2_list, vert=True)
plt.ylabel('R²')
plt.title('Distribuzione R² nei Fold (K-Fold CV)')
plt.grid(True)
plt.show()

# %%
# Analisi dei residui sui test set di tutti i fold
all_residuals = []
all_fitted = []

for train_idx, test_idx in kf.split(X):
    X_tr, X_te = X.iloc[train_idx], X.iloc[test_idx]
    y_tr, y_te = Y.iloc[train_idx], Y.iloc[test_idx]

    model = LinearRegression().fit(X_tr, y_tr)
    y_pred_te = model.predict(X_te)

    residuals = y_te - y_pred_te
    all_residuals.extend(residuals)
    all_fitted.extend(y_pred_te)

# Plot 1: Distribution of residuals
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
sns.histplot(all_residuals, kde=True, bins=30)
plt.title('Residuals Distribution (Test Sets)')
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.grid(True, alpha=0.3)

# Plot 2: Q-Q plot for normality
plt.subplot(2, 2, 2)
from scipy import stats
stats.probplot(all_residuals, dist="norm", plot=plt)
plt.title('Q-Q Plot - Residuals Normality')
plt.grid(True, alpha=0.3)

# Plot 3: Residuals vs Fitted Values
plt.subplot(2, 2, 3)
plt.scatter(all_fitted, all_residuals, alpha=0.6, s=20)
plt.axhline(0, color='red', linestyle='--', linewidth=1)
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.title('Residuals vs Predicted Values (Test)')
plt.grid(True, alpha=0.3)

# Plot 4: Boxplot of residuals
plt.subplot(2, 2, 4)
plt.boxplot(all_residuals, vert=True)
plt.ylabel('Residuals')
plt.title('Residuals Boxplot (Test Sets)')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Descriptive statistics
residuals_array = np.array(all_residuals)
print("=== Residuals Analysis on Test Sets ===")
print(f"Mean residuals: {np.mean(residuals_array):.6f}")
print(f"Standard deviation: {np.std(residuals_array):.6f}")
print(f"Skewness: {stats.skew(residuals_array):.6f}")
print(f"Kurtosis: {stats.kurtosis(residuals_array):.6f}")
print(f"Min: {np.min(residuals_array):.6f}")
print(f"Max: {np.max(residuals_array):.6f}")

# Normality test
shapiro_stat, shapiro_p = stats.shapiro(residuals_array)
print(f"\nShapiro-Wilk test for normality:")
print(f"Statistic: {shapiro_stat:.6f}, p-value: {shapiro_p:.6f}")
# Out:
# === Residuals Analysis on Test Sets ===
# Mean residuals: 0.002381
# Standard deviation: 0.165545
# Skewness: 0.750918
# Kurtosis: 2.642996
# Min: -0.586153
# Max: 0.833987
#
# Shapiro-Wilk test for normality:
# Statistic: 0.959541, p-value: 0.000000

# %% [markdown]
# Il grafico mostra una distribuzione dei residui centrata attorno a zero, con una forma quasi simmetrica e leggermente asimmetrica a destra. Questo indica che il modello di regressione lineare non presenta bias evidenti e ha errori ben distribuiti. L'assenza di outlier marcati suggerisce una buona capacità predittiva e una stabilità nei diversi fold.

# %% [markdown]
# # Modello Lineare con Solo Variabili Significative
#
# Dopo aver identificato le variabili significative tramite K-Fold CV, creiamo un modello "ridotto" utilizzando solo queste variabili. Questo approccio può migliorare:
# - **Interpretabilità**: modello più semplice da comprendere
# - **Generalizzazione**: riduce overfitting
# - **Efficienza computazionale**: meno parametri da stimare
# - **Stabilità**: meno sensibile a variazioni nei dati

# %%
# Identifichiamo le variabili significative dal modello completo
# (escludendo l'intercetta)
significant_features = significant_vars.drop('intercept', errors='ignore').index.tolist()
print("Variabili significative identificate:")
print(significant_features)
print(f"\nNumero di variabili significative: {len(significant_features)}")
print(f"Numero totale di variabili originali: {len(X.columns)}")
print(f"Riduzione: {len(X.columns) - len(significant_features)} variabili")
# Out:
# Variabili significative identificate:
# ['max_speed', 'cruise_speed', 'fuel_tank', 'all_eng_roc', 'out_eng_roc', 'takeoff_distance', 'landing_distance', 'empty_weight', 'wing_span']
#
# Numero di variabili significative: 9
# Numero totale di variabili originali: 13
# Riduzione: 4 variabili

# %%
# --- MODELLO RIDOTTO: K-Fold CV con sole variabili significative ---

# Prepara dati con sole variabili significative
X_reduced = data[significant_features]
Y_reduced = data['price']

print(f"Dimensioni dati ridotti: {X_reduced.shape}")
print(f"Variabili utilizzate: {list(X_reduced.columns)}")

# K-Fold CV per modello ridotto
kf_reduced = KFold(n_splits=10, shuffle=True, random_state=1)

# Strutture per raccogliere risultati del modello ridotto
coef_reduced_list, se_reduced_list, t_reduced_list, p_reduced_list = [], [], [], []
ci_lo_reduced_list, ci_hi_reduced_list = [], []
r2_reduced_list, mse_reduced_list = [], []

print("\nEsecuzione K-Fold CV per modello ridotto...")

for fold, (train_idx, test_idx) in enumerate(kf_reduced.split(X_reduced), 1):
    X_tr, X_te = X_reduced.iloc[train_idx], X_reduced.iloc[test_idx]
    y_tr, y_te = Y_reduced.iloc[train_idx], Y_reduced.iloc[test_idx]
    
    # Fit modello ridotto
    model_reduced = LinearRegression().fit(X_tr, y_tr)
    y_pred_tr = model_reduced.predict(X_tr)
    y_pred_te = model_reduced.predict(X_te)
    
    # Inferenza statistica
    n_tr, p_red = X_tr.shape
    resid = y_tr - y_pred_tr
    sigma2 = np.sum(resid**2) / (n_tr - p_red - 1)
    
    X_int = np.column_stack((np.ones(n_tr), X_tr.values))
    cov = sigma2 * np.linalg.inv(X_int.T @ X_int)
    se = np.sqrt(np.diag(cov))
    coef = np.concatenate(([model_reduced.intercept_], model_reduced.coef_))
    tstat = coef / se
    pval = 2 * (1 - stats.t.cdf(np.abs(tstat), df=n_tr - p_red - 1))
    ci = np.vstack((coef - 1.96*se, coef + 1.96*se)).T
    
    # Raccogli inferenza
    coef_reduced_list.append(coef)
    se_reduced_list.append(se)
    t_reduced_list.append(tstat)
    p_reduced_list.append(pval)
    ci_lo_reduced_list.append(ci[:,0])
    ci_hi_reduced_list.append(ci[:,1])
    
    # Raccogli metriche
    r2_reduced_list.append(r2_score(y_te, y_pred_te))
    mse_reduced_list.append(mean_squared_error(y_te, y_pred_te))
    
    if fold <= 3:  # Print primi 3 fold per monitoraggio
        print(f"Fold {fold}: R² = {r2_reduced_list[-1]:.4f}, MSE = {mse_reduced_list[-1]:.4f}")

print("Completato!")
# Out:
# Dimensioni dati ridotti: (507, 9)
# Variabili utilizzate: ['max_speed', 'cruise_speed', 'fuel_tank', 'all_eng_roc', 'out_eng_roc', 'takeoff_distance', 'landing_distance', 'empty_weight', 'wing_span']
#
# Esecuzione K-Fold CV per modello ridotto...
# Fold 1: R² = 0.8691, MSE = 0.0206
# Fold 2: R² = 0.9089, MSE = 0.0188
# Fold 3: R² = 0.8013, MSE = 0.0350
# Completato!

# %%
# --- Aggrega risultati modello ridotto ---
coef_reduced_arr = np.vstack(coef_reduced_list)
se_reduced_arr = np.vstack(se_reduced_list)
t_reduced_arr = np.vstack(t_reduced_list)
p_reduced_arr = np.vstack(p_reduced_list)
ci_lo_reduced_arr = np.vstack(ci_lo_reduced_list)
ci_hi_reduced_arr = np.vstack(ci_hi_reduced_list)

idx_reduced = ['intercept'] + list(X_reduced.columns)
infer_reduced_df = pd.DataFrame({
    'coef_mean': coef_reduced_arr.mean(axis=0),
    'coef_std': coef_reduced_arr.std(axis=0),
    'se_mean': se_reduced_arr.mean(axis=0),
    't_mean': t_reduced_arr.mean(axis=0),
    'p_mean': p_reduced_arr.mean(axis=0),
    'CI95_lo': ci_lo_reduced_arr.mean(axis=0),
    'CI95_hi': ci_hi_reduced_arr.mean(axis=0),
}, index=idx_reduced)

# Metriche CV modello ridotto
cv_reduced_metrics = {
    'R2_mean': np.mean(r2_reduced_list),
    'R2_std': np.std(r2_reduced_list),
    'MSE_mean': np.mean(mse_reduced_list),
    'MSE_std': np.std(mse_reduced_list)
}

print("=== RISULTATI MODELLO RIDOTTO (Solo Variabili Significative) ===")
print(f"R² mean = {cv_reduced_metrics['R2_mean']:.4f} ± {cv_reduced_metrics['R2_std']:.4f}")
print(f"MSE mean = {cv_reduced_metrics['MSE_mean']:.4f} ± {cv_reduced_metrics['MSE_std']:.4f}")

# RMSE delog
rmse_reduced_delog = np.sqrt(cv_reduced_metrics['MSE_mean']) * np.mean(np.exp(data['price']))
print(f"RMSE delog = {rmse_reduced_delog:.4f}")
print(f"\n=== Coefficienti Modello Ridotto ===")
print(infer_reduced_df)

# Verifica che tutte le variabili siano ancora significative
still_significant = infer_reduced_df[infer_reduced_df['p_mean'] < 0.05]
print(f"\nVariabili ancora significative nel modello ridotto: {len(still_significant)-1}")
if len(still_significant) < len(infer_reduced_df):
    not_significant = infer_reduced_df[infer_reduced_df['p_mean'] >= 0.05]
    print("Variabili diventate non significative:")
    print(not_significant.index.tolist())
# Out:
# === RISULTATI MODELLO RIDOTTO (Solo Variabili Significative) ===
# R² mean = 0.8291 ± 0.0643
# MSE mean = 0.0271 ± 0.0080
# RMSE delog = 389179.2533
#
# === Coefficienti Modello Ridotto ===
#                   coef_mean  coef_std   se_mean     t_mean    p_mean  \
# intercept          8.515364  0.311102  0.521004  16.368253  0.000000
# max_speed          0.178718  0.024479  0.036783   4.839938  0.000005
# cruise_speed       0.522057  0.031807  0.048300  10.807494  0.000000
# fuel_tank          0.049309  0.004813  0.013671   3.603434  0.000629
# all_eng_roc        0.124667  0.013758  0.027644   4.504984  0.000018
# out_eng_roc       -0.084420  0.007235  0.032879  -2.569997  0.012944
# takeoff_distance   0.132213  0.005834  0.038420   3.442665  0.000737
# landing_distance  -0.285489  0.058812  0.053228  -5.434293  0.000008
# empty_weight       0.109024  0.056568  0.038104   2.824113  0.005818
# wing_span          0.405106  0.057025  0.085116   4.751927  0.000041
#
# ...

# %%
# === CONFRONTO MODELLO COMPLETO vs MODELLO RIDOTTO ===

print("\n" + "="*60)
print("CONFRONTO MODELLO COMPLETO vs MODELLO RIDOTTO")
print("="*60)

comparison_df = pd.DataFrame({
    'Modello Completo': [
        len(X.columns),
        f"{cv_metrics['R2_mean']:.4f} ± {cv_metrics['R2_std']:.4f}",
        f"{cv_metrics['MSE_mean']:.4f} ± {cv_metrics['MSE_std']:.4f}",
        f"{np.sqrt(cv_metrics['MSE_mean']) * np.mean(np.exp(data['price'])):.4f}"
    ],
    'Modello Ridotto': [
        len(X_reduced.columns),
        f"{cv_reduced_metrics['R2_mean']:.4f} ± {cv_reduced_metrics['R2_std']:.4f}",
        f"{cv_reduced_metrics['MSE_mean']:.4f} ± {cv_reduced_metrics['MSE_std']:.4f}",
        f"{rmse_reduced_delog:.4f}"
    ],
    'Differenza': [
        len(X.columns) - len(X_reduced.columns),
        f"{cv_metrics['R2_mean'] - cv_reduced_metrics['R2_mean']:.4f}",
        f"{cv_metrics['MSE_mean'] - cv_reduced_metrics['MSE_mean']:.4f}",
        f"{(np.sqrt(cv_metrics['MSE_mean']) * np.mean(np.exp(data['price']))) - rmse_reduced_delog:.4f}"
    ]
}, index=['N° Variabili', 'R² (mean ± std)', 'MSE (mean ± std)', 'RMSE delog'])

print(comparison_df)

# Calcola miglioramento percentuale
r2_improvement = ((cv_reduced_metrics['R2_mean'] - cv_metrics['R2_mean']) / cv_metrics['R2_mean']) * 100
mse_improvement = ((cv_metrics['MSE_mean'] - cv_reduced_metrics['MSE_mean']) / cv_metrics['MSE_mean']) * 100

print(f"\n=== ANALISI MIGLIORAMENTO ====")
print(f"Riduzione variabili: {((len(X.columns) - len(X_reduced.columns)) / len(X.columns)) * 100:.1f}%")
print(f"Variazione R²: {r2_improvement:+.2f}%")
print(f"Variazione MSE: {mse_improvement:+.2f}% {'(miglioramento)' if mse_improvement > 0 else '(peggioramento)'}")

if cv_reduced_metrics['R2_mean'] >= cv_metrics['R2_mean'] * 0.95:  # Se mantiene almeno 95% dell'R²
    print("\n✅ Il modello ridotto mantiene performance comparabili con maggiore semplicità!")
else:
    print("\n⚠️  Il modello ridotto mostra una riduzione significativa delle performance.")
# Out:
# ...
# CONFRONTO MODELLO COMPLETO vs MODELLO RIDOTTO
# ...
#                  Modello Completo  Modello Ridotto Differenza
# N° Variabili                   13                9          4
# R² (mean ± std)   0.8282 ± 0.0585  0.8291 ± 0.0643    -0.0009
# MSE (mean ± std)  0.0275 ± 0.0080  0.0271 ± 0.0080     0.0003
# RMSE delog            391503.2695      389179.2533  2324.0163
#
# === ANALISI MIGLIORAMENTO ====
# Riduzione variabili: 30.8%
# Variazione R²: +0.11%
# Variazione MSE: +1.18% (miglioramento)
#
# ✅ Il modello ridotto mantiene performance comparabili con maggiore semplicità!

# %%
# Analisi dei residui sui test set di tutti i fold
all_residuals = []
all_fitted = []

for train_idx, test_idx in kf.split(X):
    X_tr, X_te = X.iloc[train_idx], X.iloc[test_idx]
    y_tr, y_te = Y.iloc[train_idx], Y.iloc[test_idx]

    model = LinearRegression().fit(X_tr, y_tr)
    y_pred_te = model.predict(X_te)

    residuals = y_te - y_pred_te
    all_residuals.extend(residuals)
    all_fitted.extend(y_pred_te)

# Plot 1: Distribution of residuals
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
sns.histplot(all_residuals, kde=True, bins=30)
plt.title('Residuals Distribution (Test Sets)')
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.grid(True, alpha=0.3)

# Plot 2: Q-Q plot for normality
plt.subplot(2, 2, 2)
from scipy import stats
stats.probplot(all_residuals, dist="norm", plot=plt)
plt.title('Q-Q Plot - Residuals Normality')
plt.grid(True, alpha=0.3)

# Plot 3: Residuals vs Fitted Values
plt.subplot(2, 2, 3)
plt.scatter(all_fitted, all_residuals, alpha=0.6, s=20)
plt.axhline(0, color='red', linestyle='--', linewidth=1)
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.title('Residuals vs Predicted Values (Test)')
plt.grid(True, alpha=0.3)

# Plot 4: Boxplot of residuals
plt.subplot(2, 2, 4)
plt.boxplot(all_residuals, vert=True)
plt.ylabel('Residuals')
plt.title('Residuals Boxplot (Test Sets)')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Descriptive statistics
residuals_array = np.array(all_residuals)
print("=== Residuals Analysis on Test Sets ===")
print(f"Mean residuals: {np.mean(residuals_array):.6f}")
print(f"Standard deviation: {np.std(residuals_array):.6f}")
print(f"Skewness: {stats.skew(residuals_array):.6f}")
print(f"Kurtosis: {stats.kurtosis(residuals_array):.6f}")
print(f"Min: {np.min(residuals_array):.6f}")
print(f"Max: {np.max(residuals_array):.6f}")

# Normality test
shapiro_stat, shapiro_p = stats.shapiro(residuals_array)
print(f"\nShapiro-Wilk test for normality:")
print(f"Statistic: {shapiro_stat:.6f}, p-value: {shapiro_p:.6f}")
# Out:
# === Residuals Analysis on Test Sets ===
# Mean residuals: 0.002381
# Standard deviation: 0.165545
# Skewness: 0.750918
# Kurtosis: 2.642996
# Min: -0.586153
# Max: 0.833987
#
# Shapiro-Wilk test for normality:
# Statistic: 0.959541, p-value: 0.000000

# %% [markdown]
# ## Stepforward Regression using Cp

# %% [markdown]
# useremo tutte le variabili e ci penserà la stepforward regression a selezionare le variabili più significative

# %%
from statsmodels .api import OLS
import sklearn. model_selection as skm
import sklearn. linear_model as skl
from sklearn. preprocessing import StandardScaler
from ISLP import load_data
from ISLP.models import ModelSpec as MS
from functools import partial
from sklearn. pipeline import Pipeline
from sklearn. decomposition import PCA
from sklearn. cross_decomposition import PLSRegression
from ISLP.models import \
(Stepwise ,
sklearn_selected ,
sklearn_selection_path )

# %%
def nCp(sigma2 , estimator , X, Y):
    # Calcola il numero di parametri stimati
    n, p = X.shape
    Yhat = estimator .predict(X)
    RSS = np.sum ((Y - Yhat)**2)
    return -(RSS + 2 * p * sigma2) / n

# %%
# Exclude non-numeric columns
numeric_columns = data.select_dtypes(include=[np.number]).columns.drop('price')
design = MS(numeric_columns).fit(data)

# Prepare the target and feature matrices
Y = np.array(data['price'])
X = design.transform(data)

# Fit the OLS model
sigma2 = OLS(Y, X).fit()

# %%
neg_Cp = partial(nCp , sigma2)

# %%
strategy = Stepwise . first_peak (design ,
direction ='forward ',
max_terms =len(design.terms))

# %%
data_MSE = sklearn_selected (OLS ,
strategy )
data_MSE .fit(data ,Y)
data_MSE . selected_state_
# Out:
# ('all_eng_roc',
#  'cruise_speed',
#  'empty_weight',
#  'engine_power',
#  'fuel_tank',
#  'landing_distance',
#  'length',
#  'max_speed',
#  'out_eng_roc',
#  'range',
#  'stall_speed',
#  'takeoff_distance',
#  'wing_span')

# %%
# Ensure sigma2 is a numeric value (variance of residuals)
sigma2_value = sigma2.mse_resid  # Extract the mean squared error of residuals from the model

# Redefine neg_Cp with the correct sigma2 value
neg_Cp = partial(nCp, sigma2_value)

# Use the corrected neg_Cp in the sklearn_selected function
data_Cp = sklearn_selected(OLS, strategy, scoring=neg_Cp)
data_Cp.fit(data, Y)
data_Cp.selected_state_
# Out:
# ('all_eng_roc',
#  'cruise_speed',
#  'empty_weight',
#  'fuel_tank',
#  'landing_distance',
#  'length',
#  'max_speed',
#  'out_eng_roc',
#  'takeoff_distance',
#  'wing_span')

# %%
# Elenco dei predittori
selected = list(data_Cp.selected_state_)

# Matrice X con costante
X_best = sm.add_constant(data[selected])

# Risposta
y = data['price']

# Fit OLS
model_best = sm.OLS(y, X_best).fit()

# Sommario completo
print(model_best.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.864
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                     316.4
# Date:                Wed, 18 Jun 2025   Prob (F-statistic):          5.10e-208
# Time:                        21:25:06   Log-Likelihood:                 236.41
# No. Observations:                 507   AIC:                            -450.8
# Df Residuals:                     496   BIC:                            -404.3
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                8.1237      0.537     15.136      0.000       7.069       9.178
# ...

# %%
#VIF
vif_data = pd.DataFrame()
vif_data["Regressor"] = X_best.columns
vif_data["VIF"] = [VIF(X_best.values, i) for i in range(X_best.shape[1])]
vif_data = vif_data.sort_values("VIF", ascending=False)
print(vif_data)
# Out:
#            Regressor          VIF
# 0              const  6200.822106
# 5   landing_distance    37.460007
# 6             length    18.442284
# 3       empty_weight    16.117123
# 4          fuel_tank    12.734037
# 2       cruise_speed     9.184887
# 1        all_eng_roc     5.522248
# 10         wing_span     5.514745
# 7          max_speed     5.291326
# 8        out_eng_roc     4.915602
# 9   takeoff_distance     4.453505

# %%
# Definizione della funzione per il Cp negativo
def nCp(sigma2, estimator, X, Y):
    n, p = X.shape
    Yhat = estimator.predict(X)
    RSS = np.sum((Y - Yhat) ** 2)
    return -(RSS + 2 * p * sigma2) / n

# Preparazione dei dati a partire da data2
# (assicurati che data2 sia già caricato e pulito)
numeric_cols = data.select_dtypes(include=[np.number]).columns.drop('price')
design2 = MS(numeric_cols).fit(data)

Y2 = np.array(data['price'])
X2 = design2.transform(data)

# Stima di sigma2 tramite OLS
sigma2_mod = OLS(Y2, X2).fit()
sigma2_val = sigma2_mod.mse_resid

# Scorer per Cp
neg_Cp = partial(nCp, sigma2_val)

# Strategia stepwise forward basata su Mallows Cp
strategy2 = Stepwise.first_peak(
    design2,
    direction='forward',
    max_terms=len(design2.terms)
)

# Selezione del modello
model2_Cp = sklearn_selected(OLS, strategy2, scoring=neg_Cp)
model2_Cp.fit(data, Y2)

# Variabili selezionate
print("Variabili selezionate:", model2_Cp.selected_state_)
# Out:
# Variabili selezionate: ('all_eng_roc', 'cruise_speed', 'empty_weight', 'fuel_tank', 'landing_distance', 'length', 'max_speed', 'out_eng_roc', 'takeoff_distance', 'wing_span')

# %%
#Elenco predittori
selected2 = list(model2_Cp.selected_state_)
# Matrice X con costante
X_best2 = sm.add_constant(data[selected2])
# Risposta
y2 = data['price']
# Fit OLS
model_best2 = sm.OLS(y2, X_best2).fit()
# Sommario completo
print(model_best2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.864
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                     316.4
# Date:                Wed, 18 Jun 2025   Prob (F-statistic):          5.10e-208
# Time:                        21:25:07   Log-Likelihood:                 236.41
# No. Observations:                 507   AIC:                            -450.8
# Df Residuals:                     496   BIC:                            -404.3
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                8.1237      0.537     15.136      0.000       7.069       9.178
# ...

# %%
#VIF
vif_data = pd.DataFrame()
vif_data["Regressor"] = X_best2.columns
vif_data["VIF"] = [VIF(X_best2.values, i) for i in range(X_best2.shape[1])]
vif_data = vif_data.sort_values("VIF", ascending=False)
print(vif_data)
# Out:
#            Regressor          VIF
# 0              const  6200.822106
# 5   landing_distance    37.460007
# 6             length    18.442284
# 3       empty_weight    16.117123
# 4          fuel_tank    12.734037
# 2       cruise_speed     9.184887
# 1        all_eng_roc     5.522248
# 10         wing_span     5.514745
# 7          max_speed     5.291326
# 8        out_eng_roc     4.915602
# 9   takeoff_distance     4.453505

# %% [markdown]
# ### Stepforward regression with Cross Validation

# %%
from sklearn.model_selection import KFold
from statsmodels.api import OLS, add_constant

# Usa le variabili selezionate da stepforward
step_vars = selected2
X = data[step_vars]
y = data['price']

kf = KFold(n_splits=10, shuffle=True, random_state=1)
r2_step_list = []
mse_step_list = []

for train_idx, test_idx in kf.split(X):
    X_tr, X_te = X.iloc[train_idx], X.iloc[test_idx]
    y_tr, y_te = y.iloc[train_idx], y.iloc[test_idx]
    X_tr_const = add_constant(X_tr)
    X_te_const = add_constant(X_te)
    model = OLS(y_tr, X_tr_const).fit()
    y_pred = model.predict(X_te_const)
    r2 = model.rsquared
    mse = np.mean((y_te - y_pred) ** 2)
    r2_step_list.append(r2)
    mse_step_list.append(mse)

print("Stepwise K-Fold R2 mean:", np.mean(r2_step_list))
print("Stepwise K-Fold MSE mean:", np.mean(mse_step_list))
#print RMSE
rmse_step = np.sqrt(np.mean(mse_step_list))
print("Stepwise K-Fold RMSE mean:", rmse_step)
# Out:
# Stepwise K-Fold R2 mean: 0.8651402626880896
# Stepwise K-Fold MSE mean: 0.026895017359741556
# Stepwise K-Fold RMSE mean: 0.1639970041181898
